# %%
# Install required packages
# !pip install transformers seqeval pandas seaborn scikit-learn

# Unzip the CADEC zip file (adjust the path if necessary)
# !unzip /content/cadec.zip -d /content/cadec
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/cadec/cadec/meddra/LIPITOR.95.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.95.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.969.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.969.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.81.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.81.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.941.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.941.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.799.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.799.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.955.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.955.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.1000.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.1000.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.56.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.56.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.766.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.766.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.772.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.772.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.42.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.42.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.982.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.982.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.996.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.996.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.564.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.564.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.202.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.202.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.216.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.216.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.570.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.570.ann
#  extracting: /content/cadec/cadec/meddra/VOLTAREN.19.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.19.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.31.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.31.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.558.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.558.ann
#  extracting: /content/cadec/cadec/meddra/ARTHROTEC.5.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.5.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.25.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.25.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.389.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.389.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.410.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.410.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.38.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.38.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.376.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.376.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.362.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.362.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.404.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.404.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.438.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.438.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.10.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.10.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.809.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.809.ann
#  extracting: /content/cadec/cadec/meddra/DICLOFENAC-POTASSIUM.1.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._DICLOFENAC-POTASSIUM.1.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.835.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.835.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.821.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.821.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.174.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.174.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.612.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.612.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.606.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.606.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.160.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.160.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.148.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.148.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.1.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.1.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.149.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.149.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.607.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.607.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.161.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.161.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.175.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.175.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.613.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.613.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.820.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.820.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.834.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.834.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.808.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.808.ann
#  extracting: /content/cadec/cadec/meddra/ARTHROTEC.11.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.11.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.439.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.439.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.363.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.363.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.405.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.405.ann
#  extracting: /content/cadec/cadec/meddra/ARTHROTEC.39.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.39.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.411.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.411.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.377.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.377.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.388.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.388.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.4.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.4.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.24.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.24.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.559.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.559.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.30.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.30.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.217.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.217.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.18.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.18.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.571.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.571.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.565.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.565.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.203.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.203.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.997.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.997.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.983.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.983.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.773.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.773.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.43.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.43.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.57.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.57.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.767.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.767.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.954.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.954.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.798.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.798.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.940.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.940.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.968.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.968.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.80.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.80.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.94.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.94.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.82.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.82.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.96.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.96.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.956.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.956.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.942.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.942.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.41.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.41.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.771.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.771.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.765.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.765.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.55.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.55.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.995.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.995.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.759.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.759.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.981.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.981.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.69.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.69.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.598.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.598.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.8.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.8.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.573.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.573.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.215.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.215.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.201.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.201.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.567.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.567.ann
#  extracting: /content/cadec/cadec/meddra/VOLTAREN.26.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.26.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.229.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.229.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.6.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.6.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.32.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.32.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.407.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.407.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.361.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.361.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.375.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.375.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.413.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.413.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.13.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.13.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.349.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.349.ann
#  extracting: /content/cadec/cadec/meddra/DICLOFENAC-POTASSIUM.2.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._DICLOFENAC-POTASSIUM.2.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.822.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.822.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.836.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.836.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.188.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.188.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.163.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.163.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.605.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.605.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.611.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.611.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.177.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.177.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.3.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.3.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.639.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.639.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.638.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.638.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.2.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.2.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.610.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.610.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.176.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.176.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.162.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.162.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.604.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.604.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.837.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.837.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.189.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.189.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.823.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.823.ann
#   inflating: /content/cadec/cadec/meddra/DICLOFENAC-POTASSIUM.3.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._DICLOFENAC-POTASSIUM.3.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.348.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.348.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.12.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.12.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.374.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.374.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.412.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.412.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.406.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.406.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.360.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.360.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.33.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.33.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.27.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.27.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.7.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.7.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.228.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.228.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.200.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.200.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.566.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.566.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.572.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.572.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.9.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.9.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.214.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.214.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.599.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.599.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.980.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.980.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.758.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.758.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.68.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.68.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.994.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.994.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.764.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.764.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.54.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.54.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.40.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.40.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.770.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.770.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.943.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.943.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.957.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.957.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.97.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.97.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.83.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.83.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.953.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.953.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.947.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.947.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.87.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.87.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.93.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.93.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.748.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.748.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.990.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.990.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.78.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.78.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.984.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.984.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.774.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.774.ann
#  extracting: /content/cadec/cadec/meddra/SOLARAZE.1.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._SOLARAZE.1.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.44.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.44.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.50.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.50.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.760.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.760.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.589.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.589.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.3.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.3.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.23.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.23.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.37.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.37.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.238.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.238.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.210.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.210.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.576.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.576.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.562.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.562.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.204.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.204.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.358.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.358.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.16.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.16.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.364.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.364.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.402.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.402.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.416.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.416.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.370.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.370.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.827.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.827.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.199.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.199.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.833.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.833.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.6.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.6.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.628.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.628.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.600.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.600.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.166.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.166.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.172.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.172.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.614.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.614.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.173.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.173.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.615.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.615.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.601.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.601.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.167.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.167.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.629.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.629.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.7.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.7.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.832.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.832.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.826.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.826.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.198.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.198.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.417.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.417.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.371.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.371.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.365.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.365.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.403.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.403.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.359.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.359.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.17.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.17.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.563.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.563.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.205.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.205.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.211.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.211.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.577.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.577.ann
#  extracting: /content/cadec/cadec/meddra/VOLTAREN.36.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.36.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.239.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.239.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.2.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.2.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.22.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.22.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.588.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.588.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.51.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.51.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.761.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.761.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.775.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.775.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.45.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.45.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.985.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.985.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.991.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.991.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.749.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.749.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.79.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.79.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.92.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.92.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.86.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.86.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.946.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.946.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.952.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.952.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.944.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.944.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.950.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.950.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.788.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.788.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.978.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.978.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.90.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.90.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.84.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.84.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.987.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.987.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.993.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.993.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.763.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.763.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.53.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.53.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.47.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.47.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.777.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.777.ann
#   inflating: /content/cadec/cadec/meddra/SOLARAZE.2.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._SOLARAZE.2.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.34.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.34.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.20.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.20.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.549.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.549.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.207.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.207.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.561.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.561.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.575.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.575.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.213.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.213.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.398.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.398.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.429.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.429.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.15.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.15.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.373.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.373.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.415.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.415.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.29.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.29.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.401.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.401.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.367.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.367.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.830.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.830.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.824.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.824.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.818.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.818.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.159.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.159.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.5.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.5.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.617.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.617.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.171.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.171.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.165.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.165.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.603.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.603.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.164.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.164.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.602.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.602.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.616.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.616.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.170.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.170.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.158.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.158.ann
#   inflating: /content/cadec/cadec/meddra/CATAFLAM.4.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._CATAFLAM.4.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.819.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.819.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.825.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.825.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.831.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.831.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.400.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.400.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.28.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.28.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.366.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.366.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.372.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.372.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.414.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.414.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.14.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.14.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.428.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.428.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.399.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.399.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.574.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.574.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.212.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.212.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.206.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.206.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.560.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.560.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.548.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.548.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.21.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.21.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.1.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.1.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.35.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.35.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.46.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.46.ann
#  extracting: /content/cadec/cadec/meddra/SOLARAZE.3.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._SOLARAZE.3.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.776.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.776.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.762.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.762.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.52.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.52.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.992.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.992.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.986.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.986.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.85.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.85.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.979.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.979.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.91.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.91.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.789.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.789.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.951.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.951.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.945.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.945.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.922.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.922.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.936.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.936.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.705.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.705.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.35.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.35.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.21.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.21.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.711.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.711.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.739.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.739.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.112.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.112.ann
#  extracting: /content/cadec/cadec/meddra/ARTHROTEC.106.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.106.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.261.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.261.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.507.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.507.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.513.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.513.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.275.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.275.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.46.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.46.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.249.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.249.ann
#  extracting: /content/cadec/cadec/meddra/ARTHROTEC.98.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.98.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN-XR.18.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN-XR.18.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.498.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.498.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.315.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.315.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.473.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.473.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.467.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.467.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.301.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.301.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.329.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.329.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.67.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.67.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.73.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.73.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.856.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.856.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.842.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.842.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.671.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.671.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.117.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.117.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.103.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.103.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.665.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.665.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.895.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.895.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.6.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.6.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.881.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.881.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.659.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.659.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN.7.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN.7.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.658.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.658.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.880.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.880.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.894.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.894.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.102.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.102.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.664.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.664.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.670.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.670.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.116.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.116.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.843.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.843.ann
#  extracting: /content/cadec/cadec/meddra/LIPITOR.857.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.857.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.72.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.72.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.328.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.328.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.66.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.66.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.466.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.466.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.300.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.300.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.314.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.314.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.472.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.472.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.499.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.499.ann
#   inflating: /content/cadec/cadec/meddra/VOLTAREN-XR.19.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._VOLTAREN-XR.19.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.99.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.99.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.248.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.248.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.512.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.512.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.274.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.274.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.260.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.260.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.506.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.506.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.107.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.107.ann
#   inflating: /content/cadec/cadec/meddra/ARTHROTEC.113.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._ARTHROTEC.113.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.738.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.738.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.20.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.20.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.710.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.710.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.704.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.704.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.34.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.34.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.937.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.937.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.923.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.923.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.909.ann
#   inflating: /content/cadec/__MACOSX/cadec/meddra/._LIPITOR.909.ann
#   inflating: /content/cadec/cadec/meddra/LIPITOR.935.ann
# ...
#   inflating: /content/cadec/cadec/text/LIPITOR.183.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.183.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.168.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.168.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.632.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.632.txt
#   inflating: /content/cadec/cadec/text/CATAFLAM.8.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._CATAFLAM.8.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.154.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.154.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.140.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.140.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.626.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.626.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.141.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.141.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.627.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.627.txt
#   inflating: /content/cadec/cadec/text/CATAFLAM.9.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._CATAFLAM.9.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.633.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.633.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.155.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.155.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.169.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.169.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.182.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.182.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.828.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.828.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.196.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.196.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.800.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.800.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.814.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.814.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.425.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.425.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.343.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.343.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.357.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.357.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.431.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.431.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.19.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.19.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.419.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.419.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.31.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.31.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.25.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.25.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.380.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.380.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.394.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.394.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.551.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.551.txt
#   inflating: /content/cadec/cadec/text/VOLTAREN.38.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._VOLTAREN.38.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.237.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.237.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.223.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.223.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.545.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.545.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.2.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.2.txt
#   inflating: /content/cadec/cadec/text/VOLTAREN.10.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._VOLTAREN.10.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.579.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.579.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.592.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.592.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.144.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.144.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.586.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.586.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.63.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.63.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.753.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.753.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.747.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.747.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.77.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.77.txt
#   inflating: /content/cadec/cadec/text/CAMBIA.2.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._CAMBIA.2.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.948.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.948.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.790.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.790.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.784.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.784.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.974.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.974.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.960.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.960.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.88.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.88.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.976.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.976.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.962.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.962.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.792.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.792.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.786.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.786.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.49.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.49.txt
#   inflating: /content/cadec/cadec/text/PENNSAID.2.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._PENNSAID.2.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.779.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.779.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.989.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.989.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.751.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.751.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.61.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.61.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.75.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.75.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.745.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.745.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.590.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.590.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.584.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.584.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.209.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.209.txt
#   inflating: /content/cadec/cadec/text/VOLTAREN.12.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._VOLTAREN.12.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.235.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.235.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.553.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.553.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.547.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.547.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.221.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.221.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.382.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.382.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.396.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.396.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.33.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.33.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.27.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.27.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.369.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.369.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.341.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.341.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.427.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.427.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.433.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.433.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.355.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.355.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.802.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.802.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.816.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.816.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.180.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.180.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.194.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.194.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.619.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.619.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.625.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.625.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.143.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.143.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.157.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.157.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.631.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.631.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.156.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.156.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.630.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.630.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.624.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.624.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.142.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.142.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.618.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.618.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.195.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.195.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.181.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.181.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.817.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.817.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.803.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.803.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.432.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.432.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.354.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.354.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.340.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.340.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.426.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.426.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.26.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.26.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.368.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.368.txt
#   inflating: /content/cadec/cadec/text/ARTHROTEC.32.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._ARTHROTEC.32.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.397.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.397.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.383.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.383.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.546.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.546.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.220.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.220.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.234.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.234.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.552.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.552.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.1.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.1.txt
#   inflating: /content/cadec/cadec/text/VOLTAREN.13.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._VOLTAREN.13.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.208.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.208.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.585.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.585.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.591.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.591.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.74.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.74.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.744.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.744.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.750.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.750.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.988.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.988.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.60.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.60.txt
#   inflating: /content/cadec/cadec/text/PENNSAID.3.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._PENNSAID.3.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.48.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.48.txt
#   inflating: /content/cadec/cadec/text/CAMBIA.1.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._CAMBIA.1.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.778.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.778.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.787.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.787.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.793.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.793.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.963.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.963.txt
#   inflating: /content/cadec/cadec/text/LIPITOR.977.txt
#   inflating: /content/cadec/__MACOSX/cadec/text/._LIPITOR.977.txt

# %%
import os
import random
import json
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
from seqeval.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# 1. Data Identification and Sample Printing

def list_ann_files(cadec_folder):
    """
    Scans the CADEC folder for subdirectories: 'original', 'meddra', and 'sct'.
    Returns a dictionary mapping each annotation type to its list of .ann file paths.
    """
    annotation_types = ['original', 'meddra', 'sct']
    ann_files = {}
    for ann_type in annotation_types:
        folder_path = os.path.join(cadec_folder, ann_type)
        if not os.path.isdir(folder_path):
            print(f"[!] Directory not found for {ann_type}: {folder_path}")
            ann_files[ann_type] = []
            continue
        files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.ann')]
        ann_files[ann_type] = files
        print(f"Found {len(files)} .ann files in folder '{ann_type}'.")
    return ann_files

def print_sample_ann(file_path, num_lines=3):
    """
    Opens a .ann file and prints the first num_lines non-empty lines.
    """
    print(f"--- {os.path.basename(file_path)} ---")
    try:
        with open(file_path, "r", encoding="utf-8", errors="replace") as f:
            count = 0
            for line in f:
                line = line.strip()
                if line:
                    print(line)
                    count += 1
                if count >= num_lines:
                    break
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
    print()

# Define CADEC folder
CADEC_FOLDER = "/content/cadec/cadec"
ann_files_dict = list_ann_files(CADEC_FOLDER)
for ann_type, files in ann_files_dict.items():
    print(f"\n--- Samples from '{ann_type}' folder ---")
    for f in files[:3]:
        print_sample_ann(f)

# 2. Parsing Functions with Two Preprocessing Strategies

def parse_and_split_ann_line(line, override_label=None):
    """
    Splits a multi-span .ann line into individual annotation dictionaries.
    """
    parts = line.strip().split("\t")
    if len(parts) < 3:
        return []
    ann_id = parts[0]
    ann_info = parts[1]
    ann_text = parts[2]
    if " | " in ann_info:
        info_parts = ann_info.split(" | ")
        if len(info_parts) < 3:
            return []
        offsets_str = info_parts[2].strip()
        label_type = override_label if override_label is not None else info_parts[1].strip()
    else:
        info_parts = ann_info.split()
        if len(info_parts) < 3:
            return []
        label_type = override_label if override_label is not None else info_parts[0]
        offsets_str = " ".join(info_parts[1:])
    subspan_strs = offsets_str.split(";")
    subspans = []
    sub_id_suffix = 0
    for sspan in subspan_strs:
        sspan_parts = sspan.strip().split()
        if len(sspan_parts) != 2:
            continue
        try:
            start = int(sspan_parts[0])
            end = int(sspan_parts[1])
        except ValueError:
            continue
        sub_id_suffix += 1
        new_id = f"{ann_id}_{sub_id_suffix}"
        subspans.append({
            "id": new_id,
            "label": label_type,
            "start": start,
            "end": end,
            "text": ann_text
        })
    return subspans

def merge_ann_line(line, override_label=None):
    """
    Merges multi-span annotations by taking the minimum start and maximum end.
    Returns a single annotation dictionary.
    """
    parts = line.strip().split("\t")
    if len(parts) < 3:
        return []
    ann_id = parts[0]
    ann_info = parts[1]
    ann_text = parts[2]
    if " | " in ann_info:
        info_parts = ann_info.split(" | ")
        if len(info_parts) < 3:
            return []
        offsets_str = info_parts[2].strip()
        label_type = override_label if override_label is not None else info_parts[1].strip()
    else:
        info_parts = ann_info.split()
        if len(info_parts) < 3:
            return []
        label_type = override_label if override_label is not None else info_parts[0]
        offsets_str = " ".join(info_parts[1:])
    subspan_strs = offsets_str.split(";")
    starts, ends = [], []
    for sspan in subspan_strs:
        sspan_parts = sspan.strip().split()
        if len(sspan_parts) != 2:
            continue
        try:
            starts.append(int(sspan_parts[0]))
            ends.append(int(sspan_parts[1]))
        except ValueError:
            continue
    if not starts or not ends:
        return []
    merged_start = min(starts)
    merged_end = max(ends)
    return [{
        "id": ann_id,
        "label": override_label if override_label is not None else label_type,
        "start": merged_start,
        "end": merged_end,
        "text": ann_text
    }]

def parse_brat_files_strategy(text_folder, ann_folder, target_label=None, strategy="split"):
    """
    Reads .txt and .ann files and applies the specified preprocessing strategy.
    """
    data_entries = []
    ann_files = [f for f in os.listdir(ann_folder) if f.endswith(".ann")]
    text_files = set(os.listdir(text_folder))
    for ann_file in ann_files:
        base_name = os.path.splitext(ann_file)[0]
        txt_file = base_name + ".txt"
        if txt_file not in text_files:
            continue
        txt_path = os.path.join(text_folder, txt_file)
        ann_path = os.path.join(ann_folder, ann_file)
        with open(txt_path, "r", encoding="utf-8", errors="replace") as f:
            text_content = f.read()
        annotations = []
        with open(ann_path, "r", encoding="utf-8", errors="replace") as f:
            for line in f:
                if not line.startswith("T"):
                    continue
                if strategy == "merge":
                    ann_list = merge_ann_line(line, override_label=target_label)
                else:
                    ann_list = parse_and_split_ann_line(line, override_label=target_label)
                annotations.extend(ann_list)
        data_entries.append({
            "id": base_name,
            "text": text_content,
            "annotations": annotations
        })
    return data_entries

# 3. Preprocessing: Tokenization & Label Alignment

def create_label_map(entity_types=None):
    if entity_types is None:
        entity_types = ["ADR"]
    labels = ["O"]
    for etype in entity_types:
        labels.append(f"B-{etype}")
        labels.append(f"I-{etype}")
    return {lab: i for i, lab in enumerate(labels)}

def char_labeling(text, annotations, entity_types):
    n = len(text)
    char_labels = ["O"] * n
    for ann in annotations:
        lbl = ann["label"]
        start = ann["start"]
        end = ann["end"]
        if lbl not in entity_types or start < 0 or end > n or start >= end:
            continue
        char_labels[start] = f"B-{lbl}"
        for i in range(start+1, end):
            char_labels[i] = f"I-{lbl}"
    return char_labels

def tokenize_and_align_labels(data_entries, model_name, label2id, entity_types, max_length=128, ignore_index=-100):
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
    all_input_ids, all_attention_masks, all_labels = [], [], []
    for entry in data_entries:
        text = entry["text"]
        annotations = entry["annotations"]
        char_labels = char_labeling(text, annotations, entity_types)
        encoding = tokenizer(text, max_length=max_length, padding="max_length", truncation=True, return_offsets_mapping=True)
        token_labels = []
        for (start, end) in encoding["offset_mapping"]:
            if start == end:
                token_labels.append(ignore_index)
            else:
                token_labels.append(label2id.get(char_labels[start], label2id["O"]))
        all_input_ids.append(encoding["input_ids"])
        all_attention_masks.append(encoding["attention_mask"])
        all_labels.append(token_labels)
    return {"input_ids": all_input_ids, "attention_mask": all_attention_masks, "labels": all_labels}

class CadecDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __len__(self):
        return len(self.encodings["input_ids"])
    def __getitem__(self, idx):
        return {
            "input_ids": torch.tensor(self.encodings["input_ids"][idx]),
            "attention_mask": torch.tensor(self.encodings["attention_mask"][idx]),
            "labels": torch.tensor(self.encodings["labels"][idx])
        }

# 4. Training & Evaluation Functions

def build_id2label(label2id):
    return {v: k for k, v in label2id.items()}

def compute_metrics_factory(label2id):
    id2label = build_id2label(label2id)
    def compute_metrics(p):
        predictions = np.argmax(p.predictions, axis=2)
        labels = p.label_ids
        true_labels, pred_labels = [], []
        for pred_seq, gold_seq in zip(predictions, labels):
            curr_true, curr_pred = [], []
            for p_i, g_i in zip(pred_seq, gold_seq):
                if g_i == -100:
                    continue
                curr_true.append(id2label[g_i])
                curr_pred.append(id2label[p_i])
            true_labels.append(curr_true)
            pred_labels.append(curr_pred)
        precision = precision_score(true_labels, pred_labels)
        recall = recall_score(true_labels, pred_labels)
        f1 = f1_score(true_labels, pred_labels)
        return {"precision": precision, "recall": recall, "f1": f1}
    return compute_metrics

def train_ner_model(train_dataset, dev_dataset, label2id, model_name="bert-base-uncased",
                    output_dir="./model_out", epochs=3, batch_size=8, ignore_mismatched_sizes=False):
    num_labels = len(label2id)
    model = AutoModelForTokenClassification.from_pretrained(
        model_name, num_labels=num_labels, ignore_mismatched_sizes=ignore_mismatched_sizes
    )
    training_args = TrainingArguments(
        output_dir=output_dir,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        logging_steps=10,
        logging_dir=f"{output_dir}/logs",
        save_total_limit=1,
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        greater_is_better=True
    )
    compute_metrics = compute_metrics_factory(label2id)
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=dev_dataset,
        compute_metrics=compute_metrics
    )
    trainer.train()
    return trainer

# 5. Extended Experiment Pipeline

def split_data(data, train_ratio=0.7, dev_ratio=0.15):
    random.shuffle(data)
    n = len(data)
    train_end = int(train_ratio * n)
    dev_end = train_end + int(dev_ratio * n)
    return data[:train_end], data[train_end:dev_end], data[dev_end:]

def run_extended_experiments():
    """
    Runs experiments across annotation schemes (original, meddra, sct),
    preprocessing strategies (split and merge), and models.
    """
    # Define folder paths for text and annotation sets
    text_folder = os.path.join(CADEC_FOLDER, "text")
    annotation_sets = {
        "original": os.path.join(CADEC_FOLDER, "original"),
        "meddra": os.path.join(CADEC_FOLDER, "meddra"),
        "sct": os.path.join(CADEC_FOLDER, "sct")
    }
    target_label = "ADR"
    strategies = ["split", "merge"]
    # model list
    models = {
        "BERT": "bert-base-uncased",
        "BioBERT": "dmis-lab/biobert-v1.1",
        "ClinicalBERT": "emilyalsentzer/Bio_ClinicalBERT",
        "SpanBERT_finetuned": "abhibisht89/spanbert-large-cased-finetuned-ade_corpus_v2",
        "SpanBERT_normal": "SpanBERT/spanbert-large-cased",
        "RoBERTa": "roberta-base"
    }

    entity_types = [target_label]
    label2id = create_label_map(entity_types)
    results = {}

    for ann_name, ann_folder in annotation_sets.items():
        print(f"\n=== Loading {ann_name} annotations ===")
        for strategy in strategies:
            print(f"\n--- Processing {ann_name} with {strategy} strategy ---")
            data_entries = parse_brat_files_strategy(text_folder, ann_folder, target_label=target_label, strategy=strategy)
            print(f"Parsed {len(data_entries)} documents.")
            train_data, dev_data, test_data = split_data(data_entries)
            print(f"Train: {len(train_data)}, Dev: {len(dev_data)}, Test: {len(test_data)}")

            for model_key, model_ckpt in models.items():
                print(f"\n--- Training {model_key} on {ann_name} ({strategy} strategy) ---")
                train_enc = tokenize_and_align_labels(train_data, model_ckpt, label2id, entity_types)
                dev_enc = tokenize_and_align_labels(dev_data, model_ckpt, label2id, entity_types)
                test_enc = tokenize_and_align_labels(test_data, model_ckpt, label2id, entity_types)

                train_ds = CadecDataset(train_enc)
                dev_ds = CadecDataset(dev_enc)
                test_ds = CadecDataset(test_enc)

                out_dir = f"./{ann_name}_{model_key}_{strategy}_results"
                ignore_flag = True if model_key in ["SpanBERT_finetuned", "SpanBERT_normal"] else False

                trainer = train_ner_model(
                    train_dataset=train_ds,
                    dev_dataset=dev_ds,
                    label2id=label2id,
                    model_name=model_ckpt,
                    output_dir=out_dir,
                    epochs=3,
                    batch_size=8,
                    ignore_mismatched_sizes=ignore_flag
                )

                dev_metrics = trainer.evaluate(dev_ds)
                test_metrics = trainer.evaluate(test_ds)
                key = f"{ann_name}_{strategy}_{model_key}"
                results[key] = {"dev": dev_metrics, "test": test_metrics}

    with open("extended_results.json", "w") as f:
        json.dump(results, f, indent=2)

    print("\n=== Extended Experiment Results ===")
    for k, v in results.items():
        print(f"{k} => {v}")
    return results

ext_results = run_extended_experiments()
